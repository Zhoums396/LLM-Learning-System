# %%
# !python --version
# Out:
# Python 3.13.1

# %%
print("hello")
# Out:
# hello

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# accelerate              1.4.0
# aiohappyeyeballs        2.4.6
# aiohttp                 3.11.13
# aiosignal               1.3.2
# asttokens               3.0.0
# attrs                   25.1.0
# certifi                 2025.1.31
# charset-normalizer      3.4.1
# colorama                0.4.6
# comm                    0.2.2
# contourpy               1.3.1
# cycler                  0.12.1
# datasets                3.3.2
# debugpy                 1.8.13
# decorator               5.2.1
# dill                    0.3.8
# et_xmlfile              2.0.0
# executing               2.2.0
# ffmpy                   0.5.0
# filelock                3.17.0
# fonttools               4.56.0
# frozenlist              1.5.0
# fsspec                  2024.12.0
# huggingface-hub         0.29.1
# idna                    3.10
# ipykernel               6.29.5
# ipython                 9.0.2
# ipython_pygments_lexers 1.1.1
# ...
